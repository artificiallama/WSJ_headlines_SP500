# %% [markdown]
# ##  Download WSJ headlines of archived articles
# The date, time, category and headline of the article is extracted using Beautiful soup and saved in .csv for years 1998-2020

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import matplotlib.pyplot as plt
import sys
import datetime
import numpy as np
import calendar
import time
# %matplotlib inline

# %% [markdown]
# ### In case an exception is raised the request is retried (maximum of 3 times).
# TODO : give_articles_nextpages() and give_articles() could be combined into one method.

# %%
ntries = 3

#Read in the pages after the first page, if they exist
def give_articles_nextpages(dtgstr,npages):
    
 tags_next = []     

 for ipage in np.arange(2,np.int(npages)+1):
    wsj_url = 'https://www.wsj.com/news/archive/'+dtgstr+'?page='+np.str(ipage)  
    for tr in np.arange(ntries):  
        if tr>=1: 
         print('\tIn nextpage^^tr = ',tr)
        try: 
            resp = requests.get(wsj_url,headers={'user-agent': 'my-app/0.0.1'})
            resp.raise_for_status()
        except requests.exceptions.HTTPError as errh:
            print ("Http Error:",errh)
            print('nextpage tr = ',tr)  
            time.sleep(5)
            continue
        except requests.exceptions.ConnectionError as errc:
            print ("Error Connecting:",errc)
            print('nextpage tr = ',tr)
            time.sleep(5)
            continue
        except requests.exceptions.Timeout as errt:
            print ("Timeout Error:",errt)
            print('nextpage tr = ',tr)  
            time.sleep(5)  
            continue  
        except requests.exceptions.RequestException as err:
            print ("Something else went wrong",err)
            print('nextpage tr = ',tr)  
            time.sleep(5)  
            continue  
        else:
            soup = BeautifulSoup(resp.text)
            tags = soup.find_all('article')
            #print('\tlen(tags) = ',len(tags))
            tags_next.extend(tags)  #articles from every page accumulate in tags_next
            break
    else:     
     print('\tTried 3 times, but to no avail')   
    
 return tags_next
    

#Read in the first page
def give_articles(dtgstr):

 tags_all = []  
      
 wsj_url = 'https://www.wsj.com/news/archive/'+dtgstr

 for tr in np.arange(ntries):  
        
     if tr>=1: 
      print('\tTry again : tr = ',tr)   
    
     try: 
          #print('\nTRYING')  
          resp = requests.get(wsj_url,headers={'user-agent': 'my-app/0.0.1'})
          resp.raise_for_status()
     except requests.exceptions.HTTPError as errh:
          print ("Http Error:",errh)
          print('**tr = ',tr)  
          time.sleep(5)
          continue
     except requests.exceptions.ConnectionError as errc:
          print ("Error Connecting:",errc)
          print('**tr = ',tr)  
          time.sleep(5)
          continue  
     except requests.exceptions.Timeout as errt:
          print ("Timeout Error:",errt)
          print('**tr = ',tr)  
          time.sleep(5)
          continue     
     except requests.exceptions.RequestException as err:
          print ("Something else went wrong",err)
          print('**tr = ',tr)  
          time.sleep(5)
          continue
     else:
          soup = BeautifulSoup(resp.text)
          tags_all = soup.find_all('article')
          #Find the total number of pages for this date from the dropdown list
          tags_npage = soup.find_all('span',class_=re.compile('WSJTheme--pagepicker-total*'))
          #print('\ttags_npage = ',tags_npage)  
          if tags_npage:
           npages =  tags_npage[0].text.split(' ')[1]
           assert npages.isdigit(), "npages is not a digit : npages = {0}, dtgstr = {1}".format(npages,dtgstr)
           if np.int(npages)>1:
            tags_nextpages = give_articles_nextpages(dtgstr,npages)
            tags_all.extend(tags_nextpages)
          break  
 else:     
  print('\tTried 3 times, but to no avail')           
    
 return tags_all

# %%
def give_articles_year(yr):

 columns = ['date', 'time','category', 'headline']

 articles_data = []
    
 dtgobj = datetime.datetime.strptime(np.str(yr)+'/01/01','%Y/%m/%d')
  
 ndays = 366 if calendar.isleap(yr) else 365    
    
 for i in np.arange(ndays):
    
  dtgstr = dtgobj.strftime('%Y/%m/%d')

  if np.int(dtgobj.strftime('%d'))%15==1:
   print('\n--',dtgstr)
  tags = give_articles(dtgstr)
  #print('\t** len = ',len(tags))
    
  for i,tt in enumerate(tags):
   if (tt.p is not None) and (tt.span is not None) and (tt.h2 is not None):
    articles_data.append([dtgstr,tt.p.text,tt.span.text,tt.h2.text])      
    ########                date,     time,    category, headline
  dtgobj += datetime.timedelta(days=1)   
 else:
  print('\nDone scraping : ',yr)   
  print('first = ',articles_data[0])
  print('# of articles = ',len(articles_data))
  articlesdf = pd.DataFrame(articles_data, columns=columns)
  articlesdf.to_csv('data_new/WSJ_headlines_'+np.str(yr)+'.csv',index=False)
  print('Done writing')

# %%
for year in np.arange(1998,2021):
 print('\nProcessing year ',year)   
 give_articles_year(year)
# Out:
# Processing year  2011
#
# -- 2011/01/01
#
# -- 2011/01/16
#
# -- 2011/01/31
#
# -- 2011/02/01
#
# -- 2011/02/16
#
# -- 2011/03/01
#
# -- 2011/03/16
#
# -- 2011/03/31
#
# -- 2011/04/01
#
# -- 2011/04/16
#
# -- 2011/05/01
#
# -- 2011/05/16
#
# -- 2011/05/31
#
# -- 2011/06/01
#
# -- 2011/06/16
#
# -- 2011/07/01
#
# -- 2011/07/16
#
# -- 2011/07/31
#
# -- 2011/08/01
#
# -- 2011/08/16
#
# -- 2011/08/31
#
# -- 2011/09/01
#
# -- 2011/09/16
#
# -- 2011/10/01
#
# -- 2011/10/16
#
# -- 2011/10/31
#
# -- 2011/11/01
#
# -- 2011/11/16
#
# -- 2011/12/01
#
# -- 2011/12/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2011/12/20
# **tr =  0
# 	Try again : tr =  1
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2011/12/23?page=5
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2011/12/31
#
# Done scraping :  2011
# first =  ['2011/01/01', '11:39 PM ET', 'Asia Business', 'Kan Vows to Push for Free-Trade Deal']
# # of articles =  71258
# Done writing
#
# Processing year  2012
#
# -- 2012/01/01
#
# -- 2012/01/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2012/01/27?page=6
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2012/01/31
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2012/01/31?page=2
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2012/02/01
#
# -- 2012/02/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2012/02/18
# **tr =  0
# 	Try again : tr =  1
#
# -- 2012/03/01
#
# -- 2012/03/16
#
# -- 2012/03/31
#
# -- 2012/04/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2012/04/07
# **tr =  0
# 	Try again : tr =  1
#
# -- 2012/04/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2012/04/17?page=2
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2012/05/01
#
# -- 2012/05/16
#
# -- 2012/05/31
#
# -- 2012/06/01
#
# -- 2012/06/16
#
# -- 2012/07/01
#
# -- 2012/07/16
#
# -- 2012/07/31
#
# -- 2012/08/01
#
# -- 2012/08/16
#
# -- 2012/08/31
#
# -- 2012/09/01
#
# -- 2012/09/16
#
# -- 2012/10/01
#
# -- 2012/10/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2012/10/25?page=4
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2012/10/31
#
# -- 2012/11/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2012/11/08?page=6
# nextpage tr =  0
# 	In nextpage^^tr =  1
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2012/11/09?page=3
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2012/11/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2012/11/30?page=2
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2012/12/01
#
# -- 2012/12/16
#
# -- 2012/12/31
#
# Done scraping :  2012
# first =  ['2012/01/01', '11:53 PM ET', 'U.S.', 'Seven More Fires Hit Los Angeles']
# # of articles =  66480
# Done writing
#
# Processing year  2013
#
# -- 2013/01/01
#
# -- 2013/01/16
#
# -- 2013/01/31
#
# -- 2013/02/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2013/02/11
# **tr =  0
# 	Try again : tr =  1
#
# -- 2013/02/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2013/02/22?page=3
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2013/03/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2013/03/15?page=2
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2013/03/16
#
# -- 2013/03/31
#
# -- 2013/04/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2013/04/10?page=3
# nextpage tr =  0
# 	In nextpage^^tr =  1
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2013/04/13
# **tr =  0
# 	Try again : tr =  1
#
# -- 2013/04/16
#
# -- 2013/05/01
#
# -- 2013/05/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2013/05/16?page=6
# nextpage tr =  0
# 	In nextpage^^tr =  1
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2013/05/30
# **tr =  0
# 	Try again : tr =  1
#
# -- 2013/05/31
#
# -- 2013/06/01
#
# -- 2013/06/16
#
# -- 2013/07/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2013/07/03?page=2
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2013/07/16
#
# -- 2013/07/31
#
# -- 2013/08/01
#
# -- 2013/08/16
#
# -- 2013/08/31
#
# -- 2013/09/01
#
# -- 2013/09/16
#
# -- 2013/10/01
#
# -- 2013/10/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2013/10/17?page=4
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2013/10/31
#
# -- 2013/11/01
#
# -- 2013/11/16
#
# -- 2013/12/01
#
# -- 2013/12/16
#
# -- 2013/12/31
#
# Done scraping :  2013
# first =  ['2013/01/01', '11:45 PM ET', 'Capital Journal', "Reaching Deals Is Hard. Here's Why"]
# # of articles =  65734
# Done writing
#
# Processing year  2014
#
# -- 2014/01/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2014/01/15?page=4
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2014/01/16
#
# -- 2014/01/31
#
# -- 2014/02/01
#
# -- 2014/02/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2014/02/18?page=5
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2014/03/01
#
# -- 2014/03/16
#
# -- 2014/03/31
#
# -- 2014/04/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2014/04/09?page=3
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2014/04/16
#
# -- 2014/05/01
#
# -- 2014/05/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2014/05/27?page=5
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2014/05/31
#
# -- 2014/06/01
#
# -- 2014/06/16
#
# -- 2014/07/01
#
# -- 2014/07/16
#
# -- 2014/07/31
#
# -- 2014/08/01
#
# -- 2014/08/16
#
# -- 2014/08/31
#
# -- 2014/09/01
#
# -- 2014/09/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2014/09/25?page=5
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2014/10/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2014/10/08?page=3
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2014/10/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2014/10/23?page=4
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2014/10/31
#
# -- 2014/11/01
#
# -- 2014/11/16
#
# -- 2014/12/01
#
# -- 2014/12/16
#
# -- 2014/12/31
#
# Done scraping :  2014
# first =  ['2014/01/01', '11:58 PM ET', 'Graphics', 'Smartphone Comparison']
# # of articles =  72419
# Done writing
#
# Processing year  2015
#
# -- 2015/01/01
#
# -- 2015/01/16
#
# -- 2015/01/31
#
# -- 2015/02/01
#
# -- 2015/02/16
#
# -- 2015/03/01
#
# -- 2015/03/16
#
# -- 2015/03/31
#
# -- 2015/04/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2015/04/03?page=4
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2015/04/16
#
# -- 2015/05/01
#
# -- 2015/05/16
#
# -- 2015/05/31
#
# -- 2015/06/01
#
# -- 2015/06/16
#
# -- 2015/07/01
#
# -- 2015/07/16
#
# -- 2015/07/31
#
# -- 2015/08/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2015/08/07?page=4
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2015/08/16
#
# -- 2015/08/31
#
# -- 2015/09/01
#
# -- 2015/09/16
#
# -- 2015/10/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2015/10/15?page=6
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2015/10/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2015/10/20?page=6
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2015/10/31
#
# -- 2015/11/01
#
# -- 2015/11/16
#
# -- 2015/12/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2015/12/11?page=5
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2015/12/16
#
# -- 2015/12/31
#
# Done scraping :  2015
# first =  ['2015/01/01', '11:56 PM ET', 'Tri-state Area', 'Fire on New Year’s Eve Kills Three in Queens']
# # of articles =  67435
# Done writing
#
# Processing year  2016
#
# -- 2016/01/01
#
# -- 2016/01/16
#
# -- 2016/01/31
#
# -- 2016/02/01
#
# -- 2016/02/16
#
# -- 2016/03/01
#
# -- 2016/03/16
#
# -- 2016/03/31
#
# -- 2016/04/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2016/04/04?page=3
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2016/04/16
#
# -- 2016/05/01
#
# -- 2016/05/16
#
# -- 2016/05/31
#
# -- 2016/06/01
#
# -- 2016/06/16
#
# -- 2016/07/01
#
# -- 2016/07/16
#
# -- 2016/07/31
#
# -- 2016/08/01
#
# -- 2016/08/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2016/08/25?page=2
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2016/08/31
#
# -- 2016/09/01
#
# -- 2016/09/16
# -- 2016/10/01
#
# -- 2016/10/16
#
# -- 2016/10/31
#
# -- 2016/11/01
#
# -- 2016/11/16
#
# -- 2016/12/01
#
# -- 2016/12/16
#
# -- 2016/12/31
#
# Done scraping :  2016
# first =  ['2016/01/01', '11:59 PM ET', 'Style & Fashion', '5 Fashion Resolutions for 2016']
# # of articles =  78628
# Done writing
#
# Processing year  2017
#
# -- 2017/01/01
#
# -- 2017/01/16
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2017/01/17?page=5
# nextpage tr =  0
# 	In nextpage^^tr =  1
#
# -- 2017/01/31
#
# -- 2017/02/01
#
# -- 2017/02/16
#
# -- 2017/03/01
#
# -- 2017/03/16
#
# -- 2017/03/31
#
# -- 2017/04/01
#
# -- 2017/04/16
#
# -- 2017/05/01
# Http Error: 404 Client Error: Not Found for url: https://www.wsj.com/news/archive/2017/05/11
# **tr =  0
# 	Try again : tr =  1
#
# -- 2017/05/16
#
# -- 2017/05/31
#
# -- 2017/06/01
#
# -- 2017/06/16
#
# -- 2017/07/01
#
# -- 2017/07/16
#
# -- 2017/07/31
#
# -- 2017/08/01
#
# -- 2017/08/16
#
# -- 2017/08/31
#
# -- 2017/09/01
#
# -- 2017/09/16
#
# -- 2017/10/01
#
# -- 2017/10/16
#
# -- 2017/10/31
#
# -- 2017/11/01
#
# -- 2017/11/16
#
# -- 2017/12/01
#
# -- 2017/12/16
#
# -- 2017/12/31
#
# Done scraping :  2017
# first =  ['2017/01/01', '11:59 PM ET', 'Slideshow', 'Photos of the Day: Asia']
# # of articles =  60306
# Done writing
#
# Processing year  2018
#
# -- 2018/01/01
#
# -- 2018/01/16
#
# -- 2018/01/31
#
# -- 2018/02/01
#
# -- 2018/02/16
#
# -- 2018/03/01
#
# -- 2018/03/16
#
# -- 2018/03/31
#
# -- 2018/04/01
#
# -- 2018/04/16
#
# -- 2018/05/01
#
# -- 2018/05/16
#
# -- 2018/05/31
#
# -- 2018/06/01
#
# -- 2018/06/16
#
# -- 2018/07/01
#
# -- 2018/07/16
#
# -- 2018/07/31
#
# -- 2018/08/01
#
# -- 2018/08/16
#
# -- 2018/08/31
#
# -- 2018/09/01
#
# -- 2018/09/16
#
# -- 2018/10/01
#
# -- 2018/10/16
#
# -- 2018/10/31
#
# -- 2018/11/01
#
# -- 2018/11/16
#
# -- 2018/12/01
#
# -- 2018/12/16
#
# -- 2018/12/31
#
# Done scraping :  2018
# first =  ['2018/01/01', '11:47 PM ET', 'College Football', 'Georgia Outguns Oklahoma in Rose Bowl Epic ']
# # of articles =  49697
# Done writing
#
# Processing year  2019
#
# -- 2019/01/01
#
# -- 2019/01/16
#
# -- 2019/01/31
#
# -- 2019/02/01
#
# -- 2019/02/16
#
# -- 2019/03/01
#
# -- 2019/03/16
#
# -- 2019/03/31
#
# -- 2019/04/01
#
# -- 2019/04/16
#
# -- 2019/05/01
#
# -- 2019/05/16
#
# -- 2019/05/31
#
# -- 2019/06/01
#
# -- 2019/06/16
#
# -- 2019/07/01
#
# -- 2019/07/16
#
# -- 2019/07/31
#
# -- 2019/08/01
#
# -- 2019/08/16
#
# -- 2019/08/31
#
# -- 2019/09/01
#
# -- 2019/09/16
#
# -- 2019/10/01
#
# -- 2019/10/16
#
# -- 2019/10/31
#
# -- 2019/11/01
#
# -- 2019/11/16
#
# -- 2019/12/01
#
# -- 2019/12/16
#
# -- 2019/12/31
#
# Done scraping :  2019
# first =  ['2019/01/01', '11:04 PM ET', 'Pro VC Commentary Analysis', 'Chernova’s Take: The Pitfalls of ‘Founder-Friendly’ Deals']
# # of articles =  36325
# Done writing
#
# Processing year  2020
#
# -- 2020/01/01
#
# -- 2020/01/16
#
# -- 2020/01/31
#
# -- 2020/02/01
#
# -- 2020/02/16
#
# -- 2020/03/01
#
# -- 2020/03/16
#
# -- 2020/03/31
#
# -- 2020/04/01
#
# -- 2020/04/16
#
# -- 2020/05/01
#
# -- 2020/05/16
#
# -- 2020/05/31
#
# -- 2020/06/01
#
# -- 2020/06/16
#
# -- 2020/07/01
#
# -- 2020/07/16
#
# -- 2020/07/31
#
# -- 2020/08/01
#
# -- 2020/08/16
#
# -- 2020/08/31
#
# -- 2020/09/01
#
# -- 2020/09/16
#
# -- 2020/10/01
#
# -- 2020/10/16
#
# -- 2020/10/31
#
# -- 2020/11/01
#
# -- 2020/11/16
#
# -- 2020/12/01
#
# -- 2020/12/16
#
# -- 2020/12/31
#
# Done scraping :  2020
# first =  ['2020/01/01', '11:38 PM ET', 'Obituaries', 'Don Larsen, Who Threw the Only Perfect World Series Game, Dies at 90']
# # of articles =  26952
# Done writing
